# %% [markdown]
# # Compare SMOS/SMAP and PIOMAS SIT

# %% [markdown]
# ### Module import

# %%
import netCDF4
import numpy as np
import xarray as xr
import pyproj
import cartopy.crs as ccrs
import pylab as plt
import pyhdf
from pyhdf.SD import SD, SDC
from pyresample import geometry,kd_tree,image
from osgeo import gdal

# %%
def regrid_swath_to_swath(data,lon_in,lat_in,lon_out,lat_out,radius_of_influence = 10000,eps = 0.5,fill_value = np.nan):
    """Regrid array using nearest neighbour. Change radius_of_influence depending on dataset. Input:
        - data: data to be gridded to the other grid (input dataset)
        - lon_in/lat_in: coordinates of input dataset
        - lon_out/lat_out: coordinates of target grid
        - radius_of_influence: If no pixel is found within this distance (in meters) on the input dataset, the pixel in the output dataset will be set to nan (or another fill_value to be specified in the function below)
        - eps: measure of uncertainty, larger eps mean shorter execution time
        - fill_value: Pixel will be set to this value if no pixel is found within radius_of_influence (in meters)"""

    swath_def_in = geometry.SwathDefinition(lons=lon_in, lats=lat_in)
    swath_def_out = geometry.SwathDefinition(lons=lon_out, lats=lat_out)
    data_out = kd_tree.resample_nearest(swath_def_in, data, swath_def_out, radius_of_influence=radius_of_influence, epsilon=eps, fill_value = fill_value)
    return data_out

# %% [markdown]
# ### Load and prepare data

# %% [markdown]
# ##### SMOS SIT and geolocation

# %%
f_pmw = xr.open_dataset("/Users/vludwig/05_SINXS/02_DATA/20230430_north_mix_sit_v300.nc") # pmw = passive microwave
sit_smos = f_pmw["smos_thickness"]
sit_smap = f_pmw["smap_thickness"]
sit_combined = f_pmw["combined_thickness"]

# %%
hdf = SD("/Users/vludwig/05_SINXS/02_DATA/LongitudeLatitudeGrid-n12500-Arctic.hdf", SDC.READ)
lat = hdf.select('Latitudes')
latitude = lat[:,:]
lon = hdf.select('Longitudes')
longitude = lon[:,:]

# %% [markdown]
# ##### PIOMAS

# %%
f_piomas = netCDF4.Dataset("/Users/vludwig/Desktop/PIOMAS/hiday.H2018",mode = "r")
sit = np.reshape(f_piomas.variables["hiday"],(1,365,120,360))
sit[sit==0] = np.nan
lon = np.array(f_piomas.variables["x"])
lat = np.array(f_piomas.variables["y"])
lon_2d =np.reshape(lon,(120,360))
lat_2d =np.reshape(lat,(120,360))

# %% [markdown]
# ##### Regrid PIOMAS

# %%
sit_piomas_nsidc = regrid_swath_to_swath(sit_piomas,x_2d,y_2d,longitude,latitude,radius_of_influence=500000)

# %% [markdown]
# ### Plotting

# %%
# Combined thickness
fig = plt.figure()
ax = plt.axes(projection=ccrs.NorthPolarStereo())
ax.set_extent([-180, 180, 60,90], ccrs.PlateCarree())

ax.coastlines();
ax.gridlines();
ax.set_title("Combined SMOS/SMAP SIT, 20230430")
im = ax.pcolormesh(longitude,latitude,sit_combined,zorder=2,transform = ccrs.PlateCarree())
cb = plt.colorbar(im)
cb.set_label("SIT [cm]")
fig.show()
# Out:
# /var/folders/d6/cf68qnyn42708tqdllr3pbmjmsjrs2/T/ipykernel_54458/1192483278.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
# PIOMAS original grid
fig = plt.figure()
ax = plt.axes(projection=ccrs.NorthPolarStereo())
ax.set_extent([-180, 180, 60,90], ccrs.PlateCarree())
ax.coastlines();
ax.gridlines();
ax.set_title("PIOMAS SIT, 20180101")
im = ax.pcolormesh(x_2d,y_2d,sit[0,0,:,:],zorder=2,transform = ccrs.PlateCarree())
cb = plt.colorbar(im)
cb.set_label("SIT [cm]")
fig.show()
# Out:
# /var/folders/d6/cf68qnyn42708tqdllr3pbmjmsjrs2/T/ipykernel_54458/1277238285.py:11: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()

# %%
y_2d.mean()
# Out:
# 68.80181064814815

# %%
fig = plt.figure()
ax = plt.axes(projection=ccrs.NorthPolarStereo())
ax.set_extent([-180, 180, 60,90], ccrs.PlateCarree())
# Plot the data as usual
#z.plot(ax=ax, transform=ccrs.PlateCarree(), vmin=0, cmap='terrain') 
# Add details to the plot:
ax.coastlines();
ax.gridlines();
#ax.imshow(f[2][0,0,:,:],transform = ccrs.NorthPolarStereo())
ax.pcolormesh(longitude,latitude,sit_piomas_nsidc,zorder=2,transform = ccrs.PlateCarree())
#plt.imshow(f["combined_thickness"])
fig.show()
# Out:
# /var/folders/d6/cf68qnyn42708tqdllr3pbmjmsjrs2/T/ipykernel_80763/1870981153.py:12: UserWarning: Matplotlib is currently using module://matplotlib_inline.backend_inline, which is a non-GUI backend, so cannot show the figure.
#   fig.show()
